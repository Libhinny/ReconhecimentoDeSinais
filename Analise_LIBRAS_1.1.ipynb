# %%
import zipfile  # extrair o zip
from io import BytesIO  # reconhecer numeros binarios e converter
from PIL import Image
import matplotlib.pyplot as plt  # plotar graficos
import os  # SO do computador
import shutil  # para manipulação de arquivos e diretorios
import pandas as pd
from sklearn.preprocessing import StandardScaler  # padronizar os dados
import tensorflow as tf
import numpy as np
import matplotlib.image as mpimg
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from os.path import join
from tensorflow.keras.callbacks import EarlyStopping

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/redes/teste.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization_2 (Bat  (None, 227, 227, 1)       4
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 227, 227, 256)     6656
#
#  max_pooling2d_4 (MaxPoolin  (None, 113, 113, 256)     0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 113, 113, 256)     0
#
#  conv2d_5 (Conv2D)           (None, 113, 113, 128)     819328
#
#  max_pooling2d_5 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 56, 56, 128)       0
#
#  flatten_2 (Flatten)         (None, 401408)            0
#
#  dense_4 (Dense)             (None, 64)                25690176
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 15)                975
#
#  activation_2 (Activation)   (None, 15)                0
#
# =================================================================
# Total params: 26517139 (101.15 MB)
# Trainable params: 26517137 (101.15 MB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
history = pd.read_csv('/content/drive/MyDrive/redes/historico (1).csv')
history.head()
# Out:
#    Unnamed: 0       loss  accuracy  val_loss  val_accuracy
# 0           0  52.767059  0.578392  1.884340      0.545548
# 1           1   1.785528  0.584890  1.882474      0.545548
# 2           2   1.779973  0.584890  1.891595      0.545548
# 3           3   1.775685  0.584890  1.883875      0.545548
# 4           4   1.773129  0.584890  1.878311      0.545342

# %%
# Visualizar a perda durante o treinamento
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.yscale('log')
plt.ylim(0,70)
plt.title('Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Out:
# <ipython-input-44-7c8048adb332>:5: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,70)

# %%
from google.colab import drive
#para autenticar o caminho
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
zip_path = '/content/drive/MyDrive/redes/dataSet_colorido_libras.zip'

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/redes/dataSet_colorido_libras.zip'
extract_path = '/content/dataSet_colorido_libras'

# Extrair o conteúdo do arquivo ZIP
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Listar os arquivos no diretório de extração
extracted_files = os.listdir(extract_path)
print(f'Arquivos extraídos: {extracted_files}')
# Out:
# Arquivos extraídos: ['dataSet_colorido_libras']

# %%
for dirname, _, filenames in os.walk(
    "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train"
):
    for filename in filenames:
        print(os.path.join(dirname, filename))


bus_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/bus_renamed"
bank_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/bank_renamed"
car_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/car_renamed"
formation_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed"
hospital_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/hospital_renamed"
I_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed"
man_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed"
motorcycle_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/motorcycle_renamed"
my_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/my_renamed"
supermarket_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed"
we_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/we_renamed"
woman_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed"
you_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed"
youPlural_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you (plural)_renamed"
your_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train
jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1765.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2570.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_612.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1367.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_339.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_985.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3092.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2608.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_741.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3430.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_238.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2499.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2847.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_466.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3837.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_174.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3593.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2150.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2611.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_165.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1647.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2358.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_104.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3980.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1771.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1997.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3976.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3675.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2969.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1221.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1501.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2912.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3283.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_229.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_79.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_472.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_4203.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3102.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_992.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3059.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_781.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3409.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3231.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2589.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3990.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2680.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_1054.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_3922.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2561.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_4125.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_2565.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_217.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_690.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_423.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed/formation_1605967420_491.jpeg
# ...
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_170.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_187.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_140.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_101.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_163.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_92.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_137.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_86.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_26.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_100.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_113.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_253.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_129.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_29.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_215.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_180.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_224.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_85.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_110.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_207.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_41.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_238.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_226.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_148.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_183.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_252.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_219.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_190.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_143.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_7.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_99.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_31.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_126.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_14.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_132.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_69.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_225.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_217.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_42.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_191.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_127.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_96.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_235.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_63.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_1.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_229.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_104.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_260.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_204.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_83.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_79.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_70.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_153.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_54.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_233.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_75.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_201.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_211.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_87.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_250.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_105.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_6.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_112.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_121.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_198.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_74.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_47.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_242.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_60.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_48.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_76.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_34.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_91.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_221.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_259.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_5.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_231.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_50.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_141.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_193.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_194.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_38.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_144.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_263.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_199.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_171.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_203.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_255.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_28.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_196.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_23.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_64.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_128.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_150.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_245.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_78.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_68.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_19.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_93.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_208.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_161.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_152.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_162.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_195.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_240.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_197.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_11.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_139.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_192.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_22.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_246.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_30.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_256.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_160.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_175.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_166.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_46.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_52.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_39.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_210.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_66.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_179.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_36.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed/supermarket_1605967420_44.jpeg

# %%
# Making train val split (bank SIGN)
train_bank_image = bank_image[: int(0.8 * len(bank_image))]
val_bank_image = bank_image[int(0.2 * len(bank_image)) :]
test_bank_image = bank_image[int(0.2 * len(bank_image)) :]



# Making train val split (BUS SIGN)
train_bus_image = bus_image[: int(0.8 * len(bus_image))]
val_bus_image = bus_image[int(0.2 * len(bus_image)) :]
test_bus_image = bus_image[int(0.2 * len(bus_image)) :]


# Making train val split (car SIGN)
train_car_image = car_image[: int(0.8 * len(car_image))]
val_car_image = car_image[int(0.2 * len(car_image)) :]
test_car_image = car_image[int(0.2 * len(car_image)) :]


# Making train val split (car SIGN)
train_formation_image = formation_image[: int(0.8 * len(formation_image))]
val_formation_image = formation_image[int(0.2 * len(formation_image)) :]
test_formation_image = formation_image[int(0.2 * len(formation_image)) :]

# Making train val split (hospital SIGN)
train_hospital_image = hospital_image[: int(0.8 * len(hospital_image))]
val_hospital_image = hospital_image[int(0.2 * len(hospital_image)) :]
test_hospital_image = hospital_image[int(0.2 * len(hospital_image)) :]

# Making train val split (I SIGN)
train_I_image = I_image[: int(0.8 * len(I_image))]
val_I_image = I_image[int(0.2 * len(I_image)) :]
test_I_image = I_image[int(0.2 * len(I_image)) :]

# Making train val split (man SIGN)
train_man_image = man_image[: int(0.8 * len(man_image))]
val_man_image = man_image[int(0.2 * len(man_image)) :]
test_man_image = man_image[int(0.2 * len(man_image)) :]

# Making train val split (motorcycle SIGN)
train_motorcycle_image = motorcycle_image[: int(0.8 * len(motorcycle_image))]
val_motorcycle_image = motorcycle_image[int(0.2 * len(motorcycle_image)) :]
test_motorcycle_image = motorcycle_image[int(0.2 * len(motorcycle_image)) :]


# Making train val split (my SIGN)
train_my_image = my_image[: int(0.8 * len(my_image))]
val_my_image = my_image[int(0.2 * len(my_image)) :]
test_my_image = my_image[int(0.2 * len(my_image)) :]

# Making train val split (supermarket SIGN)
train_supermarket_image = supermarket_image[: int(0.8 * len(supermarket_image))]
val_supermarket_image = supermarket_image[int(0.2 * len(supermarket_image)) :]
test_supermarket_image = supermarket_image[int(0.2 * len(supermarket_image)) :]


# Making train val split (we SIGN)
train_we_image = we_image[: int(0.8 * len(we_image))]
val_we_image = we_image[int(0.2 * len(we_image)) :]
test_we_image = we_image[int(0.2 * len(we_image)) :]


# Making train val split (woman SIGN)
train_woman_image = woman_image[: int(0.8 * len(woman_image))]
val_woman_image = woman_image[int(0.2 * len(woman_image)) :]
test_woman_image = woman_image[int(0.2 * len(woman_image)) :]

# Making train val split (you SIGN)
train_you_image = you_image[: int(0.8 * len(you_image))]
val_you_image = you_image[int(0.2* len(you_image)) :]
test_you_image = you_image[int(0.2* len(you_image)) :]

# Making train val split (youPlural SIGN)
train_youPlural_image = youPlural_image[: int(0.8 * len(youPlural_image))]
val_youPlural_image = youPlural_image[int(0.2 * len(youPlural_image)) :]
test_youPlural_image = youPlural_image[int(0.2 * len(youPlural_image)) :]


# Making train val split (your SIGN)
train_your_image = your_image[: int(0.8 * len(your_image))]
val_your_image = your_image[int(0.2 * len(your_image)) :]
test_your_image = your_image[int(0.2 * len(your_image)) :]


train_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train"
val_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/validation/validation"
test_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/test"

# %%
train_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/250.,
)

val_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255.,
)

test_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255.,
)

train_dataset = train_data_gen.flow_from_directory(
    train_dir, target_size=(227, 227), class_mode="categorical", color_mode="grayscale", batch_size=32
)

val_dataset = val_data_gen.flow_from_directory(
    val_dir, target_size=(227, 227), class_mode="categorical", color_mode="grayscale", batch_size=32
)

test_dataset = test_data_gen.flow_from_directory(
    test_dir, target_size=(227, 227), class_mode="categorical", color_mode="grayscale", batch_size=32
)
# Out:
# Found 7386 images belonging to 15 classes.
# Found 3767 images belonging to 15 classes.
# Found 1845 images belonging to 15 classes.

# %%
from sklearn.metrics import accuracy_score

# Obter as previsões do modelo no conjunto de validação
y_pred = new_model.predict(val_dataset)
y_pred_classes = np.argmax(y_pred, axis=1)

# Obter os rótulos reais do conjunto de validação
y_true = val_dataset.classes

# Calcular a acurácia
accuracy = accuracy_score(y_true, y_pred_classes)
print(f'Acurácia: {accuracy * 100:.2f}%')
# Out:
# 118/118 [==============================] - 1056s 9s/step
# Acurácia: 46.56%
