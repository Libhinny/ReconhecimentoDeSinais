# %%
from google.colab import drive
#para autenticar o caminho
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_path = '/content/drive/MyDrive/redes/dataSet_colorido_libras.zip'

# %%
import zipfile
import os

zip_path = '/content/drive/MyDrive/redes/dataSet_colorido_libras.zip'
extract_path = '/content/dataSet_colorido_libras'

# Extrair o conteúdo do arquivo ZIP
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Listar os arquivos no diretório de extração
extracted_files = os.listdir(extract_path)
print(f'Arquivos extraídos: {extracted_files}')
# Out:
# Arquivos extraídos: ['dataSet_colorido_libras']

# %%
import zipfile  # extrair o zip
from io import BytesIO  # reconhecer numeros binarios e converter
from PIL import Image
import matplotlib.pyplot as plt  # plotar graficos
import os  # SO do computador
import shutil  # para manipulação de arquivos e diretorios
import pandas as pd
from sklearn.preprocessing import StandardScaler  # padronizar os dados
import tensorflow as tf
import numpy as np
import matplotlib.image as mpimg
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from os.path import join
from tensorflow.keras.callbacks import EarlyStopping

# %%
for dirname, _, filenames in os.walk(
    "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train"
):
    for filename in filenames:
        print(os.path.join(dirname, filename))


bus_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/bus_renamed"
bank_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/bank_renamed"
car_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/car_renamed"
formation_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/formation_renamed"
hospital_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/hospital_renamed"
I_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed"
man_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed"
motorcycle_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/motorcycle_renamed"
my_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/my_renamed"
supermarket_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/supermarket_renamed"
we_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/we_renamed"
woman_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed"
you_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed"
youPlural_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you (plural)_renamed"
your_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed"


bus_image = os.listdir(bus_dir)
bank_image = os.listdir(bank_dir)
car_image = os.listdir(car_dir)
formation_image = os.listdir(formation_dir)
hospital_image = os.listdir(hospital_dir)
I_image = os.listdir(I_dir)
man_image = os.listdir(man_dir)
motorcycle_image = os.listdir(motorcycle_dir)
my_image =os.listdir(my_dir)
supermarket_image=os.listdir(supermarket_dir)
we_image=os.listdir(we_dir)
woman_image=os.listdir(woman_dir)
you_image=os.listdir(you_dir)
youPlural_image=os.listdir(youPlural_dir)
your_image=os.listdir(your_dir)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_55.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_119.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_132.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_160.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_12.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_178.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_195.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_2.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_31.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_148.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_17.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_186.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_25.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_200.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_41.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_42.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_7.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/you_renamed/you_1605967420_126.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_79.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_142.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_10.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_84.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_123.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_58.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_33.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_161.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_75.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_131.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_14.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_91.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_8.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_38.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_102.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_157.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_57.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_35.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_94.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_145.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_129.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_42.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_126.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_74.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_56.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_71.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_158.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_67.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_146.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_147.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_59.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_137.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_105.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_133.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_17.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_162.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_20.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_18.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_21.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_116.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_127.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_90.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_78.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_118.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_34.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_154.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_97.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_165.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_164.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_46.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_110.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_88.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_89.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_43.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_134.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_132.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_76.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_68.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_3.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_148.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_7.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_36.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_125.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_152.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_62.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_143.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_86.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_25.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_113.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_48.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_159.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_69.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_1.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_112.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_51.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_50.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_81.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_120.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_149.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_108.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_24.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_11.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_107.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_98.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_101.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_150.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_31.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_95.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_26.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_122.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_160.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_138.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_60.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_121.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_104.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_136.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_144.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_135.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_139.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_141.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_52.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_109.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_45.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_103.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_6.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_114.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_124.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_140.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_72.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_128.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_32.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_61.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_77.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_93.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_92.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_151.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_19.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_82.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_4.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_22.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_99.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_5.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_53.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_40.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_16.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_2.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_63.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_85.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_106.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_100.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_70.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_44.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_156.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_163.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_13.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_30.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_117.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_130.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_47.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_39.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_155.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_23.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_119.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_153.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_111.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_64.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_12.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_73.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_55.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_96.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_54.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_29.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_15.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_9.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_66.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_115.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_80.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_37.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_87.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_41.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_49.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_65.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_28.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_27.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/woman_renamed/woman_1605967420_83.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_25.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_59.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_126.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_141.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_114.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_72.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_60.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_28.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_92.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_120.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_142.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_88.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_12.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_14.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_121.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_116.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_129.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_61.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_75.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_70.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_140.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_139.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_54.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_53.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_11.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_146.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_128.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_66.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_104.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_33.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_83.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_55.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_82.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_7.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_145.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_99.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_41.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_74.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_102.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_23.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_87.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_57.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_68.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_36.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_97.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_94.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_143.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_37.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_46.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_40.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_122.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_13.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_52.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_3.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_31.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_118.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_125.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_134.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_96.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_48.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_71.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_100.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_1.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_123.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_113.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_30.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_119.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_51.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_69.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_136.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_63.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_34.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_80.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_6.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_86.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_79.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_110.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_77.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_8.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_106.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_21.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_19.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_4.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_9.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_148.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_90.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_47.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_137.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_112.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_24.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_135.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_84.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_17.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_15.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_29.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_65.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_50.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_101.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_67.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_45.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_22.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_117.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_73.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_27.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_64.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_39.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_133.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_2.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_107.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_5.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_20.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_138.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_38.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_32.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_10.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_62.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_124.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_16.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_49.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_149.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_130.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_78.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_109.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_144.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_98.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_81.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_18.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_91.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_131.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_108.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_43.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_76.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_103.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_26.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_42.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_147.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_85.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_44.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_105.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_95.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_111.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_89.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_35.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_93.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_56.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_58.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_132.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_115.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/I_renamed/I_1605967420_127.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_9.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_70.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_159.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_53.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_38.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_48.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_63.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_4.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_100.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_85.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_16.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_126.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_47.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_89.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_105.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_98.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_43.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_84.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_52.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_90.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_59.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_42.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_34.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_165.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_119.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_115.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_30.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_158.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_68.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_73.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_18.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_77.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_151.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_44.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_58.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_21.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_17.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_129.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_8.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_160.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_65.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_54.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_137.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_108.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_76.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_60.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_110.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_41.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_40.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_81.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_55.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_88.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_112.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_145.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_25.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_39.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_91.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_2.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_156.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_11.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_144.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_125.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_147.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_64.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_111.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_146.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_94.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_107.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_114.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_95.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_36.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_24.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_134.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_86.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_32.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_161.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_61.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_103.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_62.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_140.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_72.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_82.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_104.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_120.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_7.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_46.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_12.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_71.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_66.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/your_renamed/your_1605967420_143.jpeg
# ...
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_26.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_48.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_116.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_76.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_22.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_58.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_59.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_11.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_16.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_130.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_27.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_150.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_168.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_42.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_177.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_165.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_140.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_35.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_17.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_169.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_129.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_154.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_5.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_174.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_96.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_166.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_99.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_94.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_107.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_86.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_149.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_128.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_167.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_72.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_73.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_82.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_146.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_8.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_124.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_123.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_65.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_44.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_56.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_161.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_100.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_111.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_18.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_81.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_143.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_144.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_133.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_37.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_170.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_115.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_90.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_101.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_66.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_132.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_126.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_163.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_173.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_172.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_105.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_117.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_83.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_55.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_46.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_12.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_23.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_122.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_69.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_84.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_112.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_125.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_1.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_151.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_61.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_75.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_120.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_127.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_70.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_110.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_53.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_43.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_147.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_34.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_164.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_134.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_91.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_47.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_92.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_68.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_104.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_159.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_51.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_30.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_13.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_41.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_49.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_171.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_156.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_9.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_95.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_93.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_39.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_109.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_135.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_71.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_106.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_57.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_158.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_138.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_19.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_31.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_113.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_67.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_28.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_176.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_14.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_137.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_38.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_20.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_79.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_52.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_153.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_87.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_121.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_3.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_152.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_157.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_2.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_114.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_148.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_62.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_97.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_155.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_15.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_160.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_175.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_24.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_88.jpeg
# /content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train/man_renamed/man_1605967420_29.jpeg

# %%
len(bus_image),len(bank_image),len(car_image),len(formation_image), len(hospital_image), len(I_image), len(man_image), len(motorcycle_image),len(my_image), len(supermarket_image), len(we_image), len(woman_image), len(you_image), len(youPlural_image), len(your_image)
# Out:
# (268, 220, 252, 4320, 219, 150, 178, 259, 187, 267, 288, 166, 203, 241, 168)

# %%
# Making train val split (bank SIGN)
train_bank_image = bank_image[: int(0.8 * len(bank_image))]
val_bank_image = bank_image[int(0.2 * len(bank_image)) :]
test_bank_image = bank_image[int(0.2 * len(bank_image)) :]



# Making train val split (BUS SIGN)
train_bus_image = bus_image[: int(0.8 * len(bus_image))]
val_bus_image = bus_image[int(0.2 * len(bus_image)) :]
test_bus_image = bus_image[int(0.2 * len(bus_image)) :]


# Making train val split (car SIGN)
train_car_image = car_image[: int(0.8 * len(car_image))]
val_car_image = car_image[int(0.2 * len(car_image)) :]
test_car_image = car_image[int(0.2 * len(car_image)) :]


# Making train val split (car SIGN)
train_formation_image = formation_image[: int(0.8 * len(formation_image))]
val_formation_image = formation_image[int(0.2 * len(formation_image)) :]
test_formation_image = formation_image[int(0.2 * len(formation_image)) :]

# Making train val split (hospital SIGN)
train_hospital_image = hospital_image[: int(0.8 * len(hospital_image))]
val_hospital_image = hospital_image[int(0.2 * len(hospital_image)) :]
test_hospital_image = hospital_image[int(0.2 * len(hospital_image)) :]

# Making train val split (I SIGN)
train_I_image = I_image[: int(0.8 * len(I_image))]
val_I_image = I_image[int(0.2 * len(I_image)) :]
test_I_image = I_image[int(0.2 * len(I_image)) :]

# Making train val split (man SIGN)
train_man_image = man_image[: int(0.8 * len(man_image))]
val_man_image = man_image[int(0.2 * len(man_image)) :]
test_man_image = man_image[int(0.2 * len(man_image)) :]

# Making train val split (motorcycle SIGN)
train_motorcycle_image = motorcycle_image[: int(0.8 * len(motorcycle_image))]
val_motorcycle_image = motorcycle_image[int(0.2 * len(motorcycle_image)) :]
test_motorcycle_image = motorcycle_image[int(0.2 * len(motorcycle_image)) :]


# Making train val split (my SIGN)
train_my_image = my_image[: int(0.8 * len(my_image))]
val_my_image = my_image[int(0.2 * len(my_image)) :]
test_my_image = my_image[int(0.2 * len(my_image)) :]

# Making train val split (supermarket SIGN)
train_supermarket_image = supermarket_image[: int(0.8 * len(supermarket_image))]
val_supermarket_image = supermarket_image[int(0.2 * len(supermarket_image)) :]
test_supermarket_image = supermarket_image[int(0.2 * len(supermarket_image)) :]


# Making train val split (we SIGN)
train_we_image = we_image[: int(0.8 * len(we_image))]
val_we_image = we_image[int(0.2 * len(we_image)) :]
test_we_image = we_image[int(0.2 * len(we_image)) :]


# Making train val split (woman SIGN)
train_woman_image = woman_image[: int(0.8 * len(woman_image))]
val_woman_image = woman_image[int(0.2 * len(woman_image)) :]
test_woman_image = woman_image[int(0.2 * len(woman_image)) :]

# Making train val split (you SIGN)
train_you_image = you_image[: int(0.8 * len(you_image))]
val_you_image = you_image[int(0.2* len(you_image)) :]
test_you_image = you_image[int(0.2* len(you_image)) :]

# Making train val split (youPlural SIGN)
train_youPlural_image = youPlural_image[: int(0.8 * len(youPlural_image))]
val_youPlural_image = youPlural_image[int(0.2 * len(youPlural_image)) :]
test_youPlural_image = youPlural_image[int(0.2 * len(youPlural_image)) :]


# Making train val split (your SIGN)
train_your_image = your_image[: int(0.8 * len(your_image))]
val_your_image = your_image[int(0.2 * len(your_image)) :]
test_your_image = your_image[int(0.2 * len(your_image)) :]


train_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/train"
val_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/validation/validation"
test_dir = "/content/dataSet_colorido_libras/dataSet_colorido_libras/30 FPS/30 FPS/test"

# %%
# Create directories (BUS)
os.makedirs(train_dir + "/bus_renamed", exist_ok=True)
os.makedirs(val_dir + "/bus_renamed", exist_ok=True)

# Create directories (bank)
os.makedirs(train_dir + "/bank_renamed", exist_ok=True)
os.makedirs(val_dir + "/bank_renamed", exist_ok=True)

# Create directories (car)
os.makedirs(train_dir + "/car_renamed", exist_ok=True)
os.makedirs(val_dir + "/car_renamed", exist_ok=True)

# Create directories (car)
os.makedirs(train_dir + "/formation_renamed", exist_ok=True)
os.makedirs(val_dir + "/formation_renamed", exist_ok=True)

# Create directories (hospital)
os.makedirs(train_dir + "/hospital_renamed", exist_ok=True)
os.makedirs(val_dir + "/hospital_renamed", exist_ok=True)

# Create directories (I)
os.makedirs(train_dir + "/I_renamed", exist_ok=True)
os.makedirs(val_dir + "/I_renamed", exist_ok=True)

# Create directories (I)
os.makedirs(train_dir + "/man_renamed", exist_ok=True)
os.makedirs(val_dir + "/man_renamed", exist_ok=True)

# Create directories (motorcycle)
os.makedirs(train_dir + "/motorcycle_renamed", exist_ok=True)
os.makedirs(val_dir + "/motorcycle_renamed", exist_ok=True)

# Create directories (my)
os.makedirs(train_dir + "/my_renamed", exist_ok=True)
os.makedirs(val_dir + "/my_renamed", exist_ok=True)

# Create directories (supermarket)
os.makedirs(train_dir + "/supermarket_renamed", exist_ok=True)
os.makedirs(val_dir + "/supermarket_renamed", exist_ok=True)

# Create directories (we)
os.makedirs(train_dir + "/we_renamed", exist_ok=True)
os.makedirs(val_dir + "/we_renamed", exist_ok=True)

# Create directories (woman)
os.makedirs(train_dir + "/woman_renamed", exist_ok=True)
os.makedirs(val_dir + "/woman_renamed", exist_ok=True)

# Create directories (you)
os.makedirs(train_dir + "/you_renamed", exist_ok=True)
os.makedirs(val_dir + "/you_renamed", exist_ok=True)

# Create directories (youPlural)
os.makedirs(train_dir + "/you (plural)_renamed", exist_ok=True)
os.makedirs(val_dir + "/you (plural)_renamed", exist_ok=True)

# Create directories (your)
os.makedirs(train_dir + "/your_renamed", exist_ok=True)
os.makedirs(val_dir + "/your_renamed", exist_ok=True)

# %%
# Copy images to train directory (bank)
for image in train_bank_image:
    src = bank_dir + "/" + image
    dst = train_dir + "/bank_renamed"
    try:
        shutil.copy2(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (bank)
for image in val_bank_image:
    src = bank_dir + "/" + image
    dst = val_dir + "/bank_renamed"
    try:
        shutil.copy2(src, dst)
    except shutil.SameFileError:
        pass

# Copy images to train directory (bus)
for image in train_bus_image:
    src = bus_dir + "/" + image
    dst = train_dir + "/bus_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (bus)
for image in val_bus_image:
    src = bus_dir + "/" + image
    dst = val_dir + "/bus_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy images to train directory (car)
for image in train_car_image:
    src = car_dir + "/" + image
    dst = train_dir + "/car_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (car)
for image in val_car_image:
    src = car_dir + "/" + image
    dst = val_dir + "/car_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

    # Copy images to train directory (formation)
for image in train_formation_image:
    src = formation_dir + "/" + image
    dst = train_dir + "/formation_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (formation)
for image in val_formation_image:
    src = formation_dir + "/" + image
    dst = val_dir + "/formation_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

        # Copy images to train directory (hospital)
for image in train_hospital_image:
    src = hospital_dir + "/" + image
    dst = train_dir + "/hospital_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (hospital)
for image in val_hospital_image:
    src = hospital_dir + "/" + image
    dst = val_dir + "/hospital_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

        # Copy images to train directory (I)
for image in train_I_image:
    src = I_dir + "/" + image
    dst = train_dir + "/I_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (I)
for image in val_I_image:
    src = I_dir + "/" + image
    dst = val_dir + "/I_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

        # Copy images to train directory (man)
for image in train_man_image:
    src = man_dir + "/" + image
    dst = train_dir + "/man_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (man)
for image in val_man_image:
    src = man_dir + "/" + image
    dst = val_dir + "/man_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

        # Copy images to train directory (motorcycle)
for image in train_motorcycle_image:
    src = motorcycle_dir + "/" + image
    dst = train_dir + "/motorcycle_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (motorcycle)
for image in val_motorcycle_image:
    src = motorcycle_dir + "/" + image
    dst = val_dir + "/motorcycle_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

            # Copy images to train directory (my)
for image in train_my_image:
    src = my_dir + "/" + image
    dst = train_dir + "/my_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (my)
for image in val_my_image:
    src = my_dir + "/" + image
    dst = val_dir + "/my_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass


            # Copy images to train directory (supermarket)
for image in train_supermarket_image:
    src = supermarket_dir + "/" + image
    dst = train_dir + "/supermarket_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (supermarket)
for image in val_supermarket_image:
    src = supermarket_dir + "/" + image
    dst = val_dir + "/supermarket_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass


            # Copy images to train directory (we)
for image in train_we_image:
    src = we_dir + "/" + image
    dst = train_dir + "/we_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (we)
for image in val_we_image:
    src = we_dir + "/" + image
    dst = val_dir + "/we_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass


            # Copy images to train directory (woman)
for image in train_woman_image:
    src = woman_dir + "/" + image
    dst = train_dir + "/woman_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (woman)
for image in val_woman_image:
    src = woman_dir + "/" + image
    dst = val_dir + "/woman_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

     # Copy images to train directory (you)
for image in train_you_image:
    src = you_dir + "/" + image
    dst = train_dir + "/you_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (you)
for image in val_you_image:
    src = you_dir + "/" + image
    dst = val_dir + "/you_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass


     # Copy images to train directory (youPlural)
for image in train_youPlural_image:
    src = youPlural_dir + "/" + image
    dst = train_dir + "/you (plural)_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (youPlural)
for image in val_youPlural_image:
    src = youPlural_dir + "/" + image
    dst = val_dir + "/you (plural)_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

         # Copy images to train directory (your)
for image in train_your_image:
    src = your_dir + "/" + image
    dst = train_dir + "/your_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# Copy image to validation directory (your)
for image in val_your_image:
    src = your_dir + "/" + image
    dst = val_dir + "/your_renamed"
    try:
        shutil.copy(src, dst)
    except shutil.SameFileError:
        pass

# %%
# Track displayed images
displayed_images = set()

def view_random_image(target_folder, title):
    global displayed_images
    random_image = random.choice(os.listdir(target_folder))

    # Ensure the selected image hasn't been displayed before
    while random_image in displayed_images:
        random_image = random.choice(os.listdir(target_folder))

    displayed_images.add(random_image)

    img = mpimg.imread(os.path.join(target_folder, random_image))
    print(img.shape)
    plt.title(title)
    plt.imshow(img)
    plt.axis("off")
    plt.show()

# Call the function for at least three different categories
view_random_image(supermarket_dir, "supermarket")
view_random_image(woman_dir, "woman")
view_random_image(bus_dir, "bus")
# Out:
# (1280, 720, 3)
# (1280, 720, 3)
# (1280, 720, 3)

# %%
train_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/250.,
)

val_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255.,
)

test_data_gen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1/255.,
)

train_dataset = train_data_gen.flow_from_directory(
    train_dir, target_size=(227, 227), class_mode="categorical", color_mode="grayscale", batch_size=32
)

val_dataset = val_data_gen.flow_from_directory(
    val_dir, target_size=(227, 227), class_mode="categorical", color_mode="grayscale", batch_size=32
)

test_dataset = test_data_gen.flow_from_directory(
    test_dir, target_size=(227, 227), class_mode="categorical", color_mode="grayscale", batch_size=32
)
# Out:
# Found 7386 images belonging to 15 classes.
# Found 9682 images belonging to 15 classes.
# Found 1845 images belonging to 15 classes.

# %%
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras import regularizers

# Criar o modelo
model = Sequential()

# Primeira camada convolucional
model.add(BatchNormalization(input_shape=(227, 227, 1)))
model.add(Conv2D(filters=128, kernel_size=(3, 3), padding='same',  activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))
model.add(Dropout(0.2))

# Segunda camada convolucional
model.add(Conv2D(filters=64, kernel_size=(3, 3), padding='same',  activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))
model.add(Dropout(0.2))

# Terceira camada convolucional
model.add(Conv2D(filters=32, kernel_size=(3, 3), padding='same',  activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2,2)))
model.add(Dropout(0.2))


# # Quinta camada convolucional
# model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(2, 2))

# Flatten para a camada fully connected
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))  # Adiciona a camada de dropout
model.add(Dense(15, activation='softmax'))  # Especifica 'softmax' como a função de ativação

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  batch_normalization (Batch  (None, 227, 227, 1)       4
#  Normalization)
#
#  conv2d (Conv2D)             (None, 227, 227, 128)     1280
#
#  max_pooling2d (MaxPooling2  (None, 113, 113, 128)     0
#  D)
#
#  dropout (Dropout)           (None, 113, 113, 128)     0
#
#  conv2d_1 (Conv2D)           (None, 113, 113, 64)      73792
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 56, 56, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 32)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 32)        0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 64)                1605696
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 15)                975
#
# =================================================================
# Total params: 1700211 (6.49 MB)
# Trainable params: 1700209 (6.49 MB)
# Non-trainable params: 2 (8.00 Byte)
# _________________________________________________________________

# %%
# Definir otimizador, função de perda e métricas
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Configurar EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3)

# Treinar o modelo
history = model.fit(train_dataset, validation_data=val_dataset, epochs=20, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 231/231 [==============================] - 242s 998ms/step - loss: 1.1138 - accuracy: 0.6925 - val_loss: 1.3324 - val_accuracy: 0.6794
# Epoch 2/20
# 231/231 [==============================] - 204s 884ms/step - loss: 0.3326 - accuracy: 0.8852 - val_loss: 1.5730 - val_accuracy: 0.7089
# Epoch 3/20
# 231/231 [==============================] - 201s 868ms/step - loss: 0.1891 - accuracy: 0.9335 - val_loss: 1.8310 - val_accuracy: 0.7298
# Epoch 4/20
# 231/231 [==============================] - 241s 1s/step - loss: 0.1430 - accuracy: 0.9513 - val_loss: 1.8162 - val_accuracy: 0.7476

# %%
model.save('Untitled0.h5')
historico = pd.DataFrame(history.history)
historico.to_csv('historico.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Visualizar a perda durante o treinamento
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.yscale('log')
# plt.ylim(0,50)
plt.title('Training Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import accuracy_score

# Obter as previsões do modelo no conjunto de validação
y_pred = model.predict(val_dataset)
y_pred_classes = np.argmax(y_pred, axis=1)

# Obter os rótulos reais do conjunto de validação
y_true = val_dataset.classes

# Calcular a acurácia
accuracy = accuracy_score(y_true, y_pred_classes)
print(f'Acurácia: {accuracy * 100:.2f}%')
# Out:
# 303/303 [==============================] - 115s 377ms/step
# Acurácia: 33.92%

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Fazer previsões no conjunto de teste
predictions = model.predict(test_dataset)
predicted_classes = np.argmax(predictions, axis=1)

# Obter rótulos verdadeiros do conjunto de teste
true_classes = test_dataset.classes

# Calcular matriz de confusão
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Plotar matriz de confusão
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=test_dataset.class_indices.keys(), yticklabels=test_dataset.class_indices.keys())
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 58/58 [==============================] - 45s 772ms/step
